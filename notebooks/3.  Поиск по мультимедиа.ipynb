# %% [markdown]
# # Установка, импорт

# %%
pip install nemo_toolkit['all']
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nemo_toolkit[all] in /usr/local/lib/python3.9/dist-packages (1.17.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (2.0.0+cu118)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (4.65.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (1.2.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (2.12.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.13.4)
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.56.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (2.8.2)
# Requirement already satisfied: setuptools==65.5.1 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (65.5.1)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (1.3)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (1.22.4)
# Requirement already satisfied: onnx>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (1.13.1)
# Requirement already satisfied: ruamel.yaml in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.17.21)
# Requirement already satisfied: wget in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (3.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (1.14.1)
# Requirement already satisfied: matplotlib>=3.3.2 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (3.7.1)
# Requirement already satisfied: sacremoses>=0.0.43 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.0.53)
# Requirement already satisfied: fasttext in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.9.2)
# Requirement already satisfied: sacrebleu[ja] in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (2.3.1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.12.1)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.6.2)
# Requirement already satisfied: jiwer>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (2.5.2)
# Requirement already satisfied: braceexpand in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.1.7)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (1.10.1)
# Requirement already satisfied: isort<6.0.0,>5.1.0 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (5.12.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (1.26.108)
# Requirement already satisfied: sphinxcontrib-bibtex in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (2.5.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (3.8.0)
# Requirement already satisfied: opencc in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (1.1.6)
# Requirement already satisfied: librosa in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.10.0.post2)
# Requirement already satisfied: tabulate>=0.8.7 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.8.10)
# Requirement already satisfied: flask-restful in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.3.9)
# Requirement already satisfied: pyannote.metrics in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (3.2.1)
# Requirement already satisfied: gradio in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (3.24.1)
# Requirement already satisfied: pangu in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (4.0.6.1)
# Requirement already satisfied: pydub in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.25.1)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (2.13.7)
# Requirement already satisfied: torchmetrics>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.11.4)
# Requirement already satisfied: marshmallow in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (3.19.0)
# Requirement already satisfied: pypinyin-dict in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.5.0)
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.48.0)
# Requirement already satisfied: attrdict in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: sox in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: sentencepiece<1.0.0 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.1.97)
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (3.8.1)
# Requirement already satisfied: pyannote.core in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (5.0.0)
# Requirement already satisfied: nemo-text-processing in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.1.7rc0)
# Requirement already satisfied: textdistance>=4.1.5 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (4.5.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (23.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (7.2.2)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (3.5.4)
# Requirement already satisfied: g2p-en in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (2.1.0)
# Requirement already satisfied: pytorch-lightning<=1.9.4,>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (1.9.4)
# Requirement already satisfied: omegaconf<2.3,>=2.2 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (2.2.3)
# Requirement already satisfied: pyyaml<6 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (5.4.1)
# Requirement already satisfied: pytest-runner in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (6.0.0)
# Requirement already satisfied: wandb in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.14.1)
# Requirement already satisfied: kaldi-python-io in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (1.4.4)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (1.7.3)
# Requirement already satisfied: gdown in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (4.6.6)
# Requirement already satisfied: ijson in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (3.2.0.post0)
# Requirement already satisfied: hydra-core<1.3,>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (1.2.0)
# Requirement already satisfied: jieba in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.42.1)
# Requirement already satisfied: progress>=1.5 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (1.6)
# Requirement already satisfied: kaldiio in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (2.18.0)
# Requirement already satisfied: black==19.10b0 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (19.10b0)
# Requirement already satisfied: transformers>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (4.27.4)
# Requirement already satisfied: youtokentome>=1.0.5 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (1.0.6)
# Requirement already satisfied: texterrors in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.4.4)
# Requirement already satisfied: inflect in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (6.0.2)
# Requirement already satisfied: click==8.0.2 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (8.0.2)
# Requirement already satisfied: kornia in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.6.11)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (6.1.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (7.7.1)
# Requirement already satisfied: parameterized in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.9.0)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (2.2.2)
# Requirement already satisfied: webdataset<=0.1.62,>=0.1.48 in /usr/local/lib/python3.9/dist-packages (from nemo_toolkit[all]) (0.1.62)
# Requirement already satisfied: toml>=0.9.4 in /usr/local/lib/python3.9/dist-packages (from black==19.10b0->nemo_toolkit[all]) (0.10.2)
# Requirement already satisfied: pathspec<1,>=0.6 in /usr/local/lib/python3.9/dist-packages (from black==19.10b0->nemo_toolkit[all]) (0.11.1)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.9/dist-packages (from black==19.10b0->nemo_toolkit[all]) (22.2.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from black==19.10b0->nemo_toolkit[all]) (2022.10.31)
# Requirement already satisfied: typed-ast>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from black==19.10b0->nemo_toolkit[all]) (1.5.4)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.9/dist-packages (from black==19.10b0->nemo_toolkit[all]) (1.4.4)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.9/dist-packages (from hydra-core<1.3,>=1.2.0->nemo_toolkit[all]) (4.9.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.9/dist-packages (from librosa->nemo_toolkit[all]) (4.4.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.9/dist-packages (from librosa->nemo_toolkit[all]) (0.2)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.9/dist-packages (from librosa->nemo_toolkit[all]) (1.0.5)
# Requirement already satisfied: pooch<1.7,>=1.0 in /usr/local/lib/python3.9/dist-packages (from librosa->nemo_toolkit[all]) (1.6.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.9/dist-packages (from librosa->nemo_toolkit[all]) (4.5.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.9/dist-packages (from librosa->nemo_toolkit[all]) (0.3.4)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.9/dist-packages (from librosa->nemo_toolkit[all]) (1.1.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.9/dist-packages (from librosa->nemo_toolkit[all]) (3.0.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.2->nemo_toolkit[all]) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.2->nemo_toolkit[all]) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.2->nemo_toolkit[all]) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.2->nemo_toolkit[all]) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.2->nemo_toolkit[all]) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.2->nemo_toolkit[all]) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.3.2->nemo_toolkit[all]) (1.4.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->nemo_toolkit[all]) (0.39.1)
# Requirement already satisfied: protobuf<4,>=3.20.2 in /usr/local/lib/python3.9/dist-packages (from onnx>=1.7.0->nemo_toolkit[all]) (3.20.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil->nemo_toolkit[all]) (1.16.0)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<=1.9.4,>=1.9.0->nemo_toolkit[all]) (0.8.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<=1.9.4,>=1.9.0->nemo_toolkit[all]) (2023.3.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->nemo_toolkit[all]) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.9/dist-packages (from soundfile->nemo_toolkit[all]) (1.15.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch->nemo_toolkit[all]) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch->nemo_toolkit[all]) (3.10.7)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch->nemo_toolkit[all]) (3.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch->nemo_toolkit[all]) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch->nemo_toolkit[all]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch->nemo_toolkit[all]) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch->nemo_toolkit[all]) (16.0.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.0.1->nemo_toolkit[all]) (0.13.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers>=4.0.1->nemo_toolkit[all]) (2.27.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from boto3->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: botocore<1.30.0,>=1.29.108 in /usr/local/lib/python3.9/dist-packages (from boto3->nemo_toolkit[all]) (1.29.108)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from boto3->nemo_toolkit[all]) (0.6.0)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.9/dist-packages (from fasttext->nemo_toolkit[all]) (2.10.4)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.9/dist-packages (from flask-restful->nemo_toolkit[all]) (2.2.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.9/dist-packages (from flask-restful->nemo_toolkit[all]) (2022.7.1)
# Requirement already satisfied: aniso8601>=0.82 in /usr/local/lib/python3.9/dist-packages (from flask-restful->nemo_toolkit[all]) (9.0.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy->nemo_toolkit[all]) (0.2.6)
# Requirement already satisfied: distance>=0.1.3 in /usr/local/lib/python3.9/dist-packages (from g2p-en->nemo_toolkit[all]) (0.1.3)
# Requirement already satisfied: pydantic>=1.9.1 in /usr/local/lib/python3.9/dist-packages (from inflect->nemo_toolkit[all]) (1.10.7)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from gdown->nemo_toolkit[all]) (4.11.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.9/dist-packages (from gradio->nemo_toolkit[all]) (0.23.3)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.9/dist-packages (from gradio->nemo_toolkit[all]) (0.3.0)
# Requirement already satisfied: websockets>=10.0 in /usr/local/lib/python3.9/dist-packages (from gradio->nemo_toolkit[all]) (11.0.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from gradio->nemo_toolkit[all]) (3.8.4)
# Requirement already satisfied: semantic-version in /usr/local/lib/python3.9/dist-packages (from gradio->nemo_toolkit[all]) (2.10.0)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.9/dist-packages (from gradio->nemo_toolkit[all]) (2.1.2)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.9/dist-packages (from gradio->nemo_toolkit[all]) (23.1.0)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.9/dist-packages (from gradio->nemo_toolkit[all]) (0.0.6)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.9/dist-packages (from gradio->nemo_toolkit[all]) (0.95.0)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /usr/local/lib/python3.9/dist-packages (from gradio->nemo_toolkit[all]) (0.3.3)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.9/dist-packages (from gradio->nemo_toolkit[all]) (0.21.1)
# Requirement already satisfied: gradio-client>=0.0.5 in /usr/local/lib/python3.9/dist-packages (from gradio->nemo_toolkit[all]) (0.0.8)
# Requirement already satisfied: orjson in /usr/local/lib/python3.9/dist-packages (from gradio->nemo_toolkit[all]) (3.8.9)
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from gradio->nemo_toolkit[all]) (4.2.2)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from gradio->nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->nemo_toolkit[all]) (3.0.7)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->nemo_toolkit[all]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->nemo_toolkit[all]) (3.6.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.5.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->nemo_toolkit[all]) (7.34.0)
# Requirement already satisfied: pynini==2.1.5 in /usr/local/lib/python3.9/dist-packages (from nemo-text-processing->nemo_toolkit[all]) (2.1.5)
# Requirement already satisfied: cdifflib in /usr/local/lib/python3.9/dist-packages (from nemo-text-processing->nemo_toolkit[all]) (1.2.6)
# Requirement already satisfied: Cython>=0.29 in /usr/local/lib/python3.9/dist-packages (from pynini==2.1.5->nemo-text-processing->nemo_toolkit[all]) (0.29.34)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.9/dist-packages (from pyannote.core->nemo_toolkit[all]) (2.4.0)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.9/dist-packages (from pyannote.metrics->nemo_toolkit[all]) (0.6.2)
# Requirement already satisfied: pyannote.database>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from pyannote.metrics->nemo_toolkit[all]) (5.0.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.9/dist-packages (from pytest->nemo_toolkit[all]) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.9/dist-packages (from pytest->nemo_toolkit[all]) (1.0.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from pytest->nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /usr/local/lib/python3.9/dist-packages (from pytest->nemo_toolkit[all]) (1.1.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /usr/local/lib/python3.9/dist-packages (from ruamel.yaml->nemo_toolkit[all]) (0.2.7)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.9/dist-packages (from sacrebleu[ja]->nemo_toolkit[all]) (2.7.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from sacrebleu[ja]->nemo_toolkit[all]) (4.9.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.9/dist-packages (from sacrebleu[ja]->nemo_toolkit[all]) (0.4.6)
# Requirement already satisfied: ipadic<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from sacrebleu[ja]->nemo_toolkit[all]) (1.0.0)
# Requirement already satisfied: mecab-python3==1.0.5 in /usr/local/lib/python3.9/dist-packages (from sacrebleu[ja]->nemo_toolkit[all]) (1.0.5)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers->nemo_toolkit[all]) (0.15.1+cu118)
# Requirement already satisfied: docutils<0.17,>=0.12 in /usr/local/lib/python3.9/dist-packages (from sphinx->nemo_toolkit[all]) (0.16)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.9/dist-packages (from sphinx->nemo_toolkit[all]) (2.14.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.9/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.4)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.9/dist-packages (from sphinx->nemo_toolkit[all]) (2.12.1)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.9/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.3)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.9/dist-packages (from sphinx->nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.9/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.9/dist-packages (from sphinx->nemo_toolkit[all]) (1.1.5)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.9/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.9/dist-packages (from sphinx->nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /usr/local/lib/python3.9/dist-packages (from sphinx->nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.9/dist-packages (from sphinx->nemo_toolkit[all]) (0.7.13)
# Requirement already satisfied: pybtex-docutils>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from sphinxcontrib-bibtex->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.9/dist-packages (from sphinxcontrib-bibtex->nemo_toolkit[all]) (6.1.0)
# Requirement already satisfied: pybtex>=0.24 in /usr/local/lib/python3.9/dist-packages (from sphinxcontrib-bibtex->nemo_toolkit[all]) (0.24.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nemo_toolkit[all]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nemo_toolkit[all]) (1.53.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nemo_toolkit[all]) (2.17.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nemo_toolkit[all]) (0.40.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nemo_toolkit[all]) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nemo_toolkit[all]) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nemo_toolkit[all]) (3.4.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard->nemo_toolkit[all]) (2.2.3)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.9/dist-packages (from texterrors->nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: plac in /usr/local/lib/python3.9/dist-packages (from texterrors->nemo_toolkit[all]) (1.3.5)
# Requirement already satisfied: loguru in /usr/local/lib/python3.9/dist-packages (from texterrors->nemo_toolkit[all]) (0.6.0)
# Requirement already satisfied: Levenshtein in /usr/local/lib/python3.9/dist-packages (from texterrors->nemo_toolkit[all]) (0.20.9)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb->nemo_toolkit[all]) (5.9.4)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from wandb->nemo_toolkit[all]) (0.4.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.9/dist-packages (from wandb->nemo_toolkit[all]) (1.3.2)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb->nemo_toolkit[all]) (1.19.1)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb->nemo_toolkit[all]) (3.1.31)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.9/dist-packages (from wandb->nemo_toolkit[all]) (0.1.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio->nemo_toolkit[all]) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio->nemo_toolkit[all]) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio->nemo_toolkit[all]) (4.3.3)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.9/dist-packages (from botocore<1.30.0,>=1.29.108->boto3->nemo_toolkit[all]) (1.26.15)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0->soundfile->nemo_toolkit[all]) (2.21)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from Flask>=0.8->flask-restful->nemo_toolkit[all]) (2.1.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio->nemo_toolkit[all]) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio->nemo_toolkit[all]) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio->nemo_toolkit[all]) (1.8.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio->nemo_toolkit[all]) (2.0.12)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio->nemo_toolkit[all]) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio->nemo_toolkit[all]) (6.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb->nemo_toolkit[all]) (4.0.10)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->nemo_toolkit[all]) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=3.6->sphinxcontrib-bibtex->nemo_toolkit[all]) (3.15.0)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (6.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (6.1.12)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.18.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (3.0.38)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.1.6)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.7.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio->nemo_toolkit[all]) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio->nemo_toolkit[all]) (2.0.0)
# Requirement already satisfied: typer[all]>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: latexcodec>=1.0.4 in /usr/local/lib/python3.9/dist-packages (from pybtex>=0.24->sphinxcontrib-bibtex->nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers>=4.0.1->nemo_toolkit[all]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers>=4.0.1->nemo_toolkit[all]) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch->nemo_toolkit[all]) (1.3.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (6.4.8)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->gdown->nemo_toolkit[all]) (2.4)
# Requirement already satisfied: starlette<0.27.0,>=0.26.1 in /usr/local/lib/python3.9/dist-packages (from fastapi->gradio->nemo_toolkit[all]) (0.26.1)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /usr/local/lib/python3.9/dist-packages (from httpx->gradio->nemo_toolkit[all]) (1.5.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /usr/local/lib/python3.9/dist-packages (from httpx->gradio->nemo_toolkit[all]) (0.16.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.9/dist-packages (from httpx->gradio->nemo_toolkit[all]) (1.3.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests->transformers>=4.0.1->nemo_toolkit[all]) (1.7.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.9/dist-packages (from uvicorn->gradio->nemo_toolkit[all]) (0.14.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->nemo_toolkit[all]) (5.0.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.9/dist-packages (from httpcore<0.17.0,>=0.15.0->httpx->gradio->nemo_toolkit[all]) (3.6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->nemo_toolkit[all]) (0.19.3)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.9/dist-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.17.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (6.5.4)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.16.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->nemo_toolkit[all]) (3.2.2)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (1.5.0.post1)
# Requirement already satisfied: rich<13.0.0,>=10.11.0 in /usr/local/lib/python3.9/dist-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (12.6.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (3.2.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from rich<13.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.9.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (21.2.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.7.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (6.0.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.2.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (2.16.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.5.1)

# %%
# !pip install ffmpeg-python
import ffmpeg # кроссплатформенная open-source библиотека для обработки видео- и аудиофайлов
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.9/dist-packages (0.2.0)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from ffmpeg-python) (0.18.3)

# %%
import nemo.collections.asr as nemo_asr
asr_model = nemo_asr.models.EncDecRNNTBPEModel.from_pretrained("nvidia/stt_ru_conformer_transducer_large")
# Out:
# [NeMo W 2023-04-07 15:37:55 optimizers:54] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# [NeMo W 2023-04-07 15:38:00 experimental:27] Module <class 'nemo.collections.asr.modules.audio_modules.SpectrogramToMultichannelFeatures'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo I 2023-04-07 15:38:09 mixins:170] Tokenizer SentencePieceTokenizer initialized with 1024 tokens
# [NeMo W 2023-04-07 15:38:10 modelPT:161] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: null
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: true
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#     trim_silence: false
#     max_duration: 20.0
#     min_duration: 0.1
#     is_tarred: false
#     tarred_audio_filepaths: null
#     shuffle_n: 2048
#     bucketing_strategy: synced_randomized
#     bucketing_batch_size: null
#     bucketing_weights: ''
#
# [NeMo W 2023-04-07 15:38:10 modelPT:168] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: null
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: false
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#
# [NeMo W 2023-04-07 15:38:10 modelPT:174] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: null
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: false
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
# [NeMo I 2023-04-07 15:38:10 features:287] PADDING: 0
# [NeMo W 2023-04-07 15:38:11 nemo_logging:349] /usr/local/lib/python3.9/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#       warnings.warn("dropout option adds dropout after all but last "
# [NeMo I 2023-04-07 15:38:12 rnnt_models:206] Using RNNT Loss : warprnnt_numba
#     Loss warprnnt_numba_kwargs: {'fastemit_lambda': 0.0, 'clamp': -1.0}
# [NeMo I 2023-04-07 15:38:13 save_restore_connector:247] Model EncDecRNNTBPEModel was successfully restored from /root/.cache/huggingface/hub/models--nvidia--stt_ru_conformer_transducer_large/snapshots/687d02db291e931455cf321abd625ef2b7f0b1a9/stt_ru_conformer_transducer_large.nemo.

# %%
import io
from IPython.display import HTML, Audio # загружаем модуль чтобы обратиться к HTML для записи аудио с микрофона в ноутбуке
from base64 import b64decode # модуль для кодировки/раскодировки аудиозаписи(64-разрядный код)
import scipy # воспользуемся модулями библиотеки для работы со звуковой дорожкой
from scipy.io.wavfile import read as wav_read # для чтения WAV формата
from scipy.io.wavfile import write
import librosa # для параметризации аудио

from google.colab import files # модуль для загрузки файлов
from google.colab.output import eval_js

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Распознавание речи записанной с микрофона

# %%
DIR = '/content/drive/MyDrive/Colab Notebooks/HACKATHONS/Видеопереворот/Поиск/files/'

# %%
AUDIO_HTML = """
<script>
var my_div = document.createElement("DIV");
var my_p = document.createElement("P");
var my_btn = document.createElement("BUTTON");
var t = document.createTextNode("Press to start recording");

my_btn.appendChild(t);
my_div.appendChild(my_btn);
document.body.appendChild(my_div);

var base64data = 0;  // будем использовать для аудиоданных метод кодирования информации в 64-разрядный код
var reader;  // создаем переменную для чтения файла
var recorder, gumStream; // объявляем переменные для записи данных/потока
var recordButton = my_btn; //  создаем переменную для кнопки записи аудио с микрофона

var handleSuccess = function(stream) {  // объявляем функцию для работы с потоками данных
  gumStream = stream;  // создаем переменную для потока
  var options = {
    mimeType : 'audio/webm;codecs=opus' // в опциях задаем медиа тип с аудиоформатом и кодеками
  };            
  recorder = new MediaRecorder(stream); // создаем новый объект MediaRecorder, получающий медиапоток для записи.
  // MediaRecorder - интерфейс MediaStream Recording API представляющий функциональность для простой записи медиа. Создается..
  // ..с использованием MediaRecorder() конструктора.
  recorder.ondataavailable = function(e) {  // вызываем обработчик dataavailable события, запускаемое по окончанию записи          
    var url = URL.createObjectURL(e.data); // этим методом создаем DOMString(UTF-16 String), содержащий URL с указанием на объект e.data
    var preview = document.createElement('audio'); // создаем элемент-тег аудио
    preview.controls = true; // активизируем элементы управления
    preview.src = url; // берем в кач-ве исходных данных файл, содержащийся в записанной ранее URL
    document.body.appendChild(preview); //добавляем элемент аудио в <body>("тело", для хранения содержимого веб-страницы)

    reader = new FileReader();  // создаем объект класса FileReader для чтения разных источников данных
    reader.readAsDataURL(e.data);  // читаем содержимое указанного файла
    reader.onloadend = function() {  // обработчик события, запускаемого после передачи данных
      base64data = reader.result; // записываем прочитанное содержимое в base64data
    }
  };
  recorder.start();  // начало записи медиа
  };

recordButton.innerText = "Идёт запись... нажмите для остановки"; // такой текст будет на кнопке BUTTON во время записи аудио

// запрос разрешения пользователя на доступ к устройству захвата аудио(микрофон), указываем True
navigator.mediaDevices.getUserMedia({audio: true}).then(handleSuccess);


function toggleRecording() {  // функция опишет действия по завершению записи (после клика мышкой по кнопке "Recording... press to stop")
  if (recorder && recorder.state == "recording") {  // если рекордер находится в процессе записи 
      recorder.stop();  // рекордер прерывается
      gumStream.getAudioTracks()[0].stop();  // отключается запись и доступ к микрофону
      recordButton.innerText = "Saving the recording... pls wait!" // эта надпись(сохранение записи) отобразится на кнопке BUTTON 
  }
}

function sleep(ms) {  // создаем функцию с задержкой вызова
  return new Promise(resolve => setTimeout(resolve, ms));  
  // new Promise - конструкция для отложенных вычислений
  // setTimeout позволяет вызвать функцию один раз через определённый интервал времени
}

var data = new Promise(resolve=>{
  recordButton.onclick = ()=>{  // при нажатии левой кнопкой мыши на кнопку "Recording... press to stop"
    toggleRecording()  // вызывается функция завершения аудиозаписи
    sleep(2000).then(() => {  // и после задержки 2000мс(2 сек)
      resolve(base64data.toString())  // полученные данные из формата base64 преобразовываем в строку
    });
  }
});
      
</script>
"""

def get_audio(): # объявляем функцию извлечения аудио, записанного через микрофон в ноутбуке
  display(HTML(AUDIO_HTML)) # c помощью модулей библиотеки IPython отображаем результат выполнения записанного выше скрипта AUDIO_HTML
  data = eval_js("data") # данные на выходе запишем в data как результат выполнения javascript кода
  # data сейчас в таком виде: 'data:audio/webm;codecs=opus;base64,GkXfo59ChoEBQveBAULygQRC84EIQoKEd2VibUKHgQRChYE...mpZpkq1'
  binary = b64decode(data.split(',')[1]) #отсекаем информацию "data:audio/webm;codecs=opus;base64", оставляем только данные и декодируем
  # b'\x1aE\xdf\xa3\x9fB\x86\x81\x01B\xf7\x81\x01B\xf2

  process = (ffmpeg
    .input('pipe:0') # поток стандартного ввода
    .output('pipe:1', format='wav') # стандартного вывода в формате wav 
    .run_async(pipe_stdin=True, pipe_stdout=True, pipe_stderr=True, quiet=True, overwrite_output=True)) # асинхронное выполнение командной строки FFmpeg
  # binary преобразовываем в wav, с типичным для медиафайлов форматом RIFF(ResourceInterchangeFileFormat - формат файла для обмена ресурсами)
  output, err = process.communicate(input=binary)
  # output - b'RIFF\xff\xff\xff\xffWAVEfmt \x10\x00\x00\x00\x01\x00\x01\x00\x80\xbb\x00\x00\...\x01\x00\x01\x00\x01\x0\xff'
  # err - b"ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers\n...headers:0kB muxing overhead: 0.046695%\n"


  # Cодержимое файла группируется из отдельных секций (chunks) - формат выборок аудиоданных. Секция имеет свой заголовок и данные секции.
  # Размер заголовка секции RIFF - 8 байт, их ниже уберём из определения размера секции RIFF
  riff_chunk_size = len(output) - 8 
  # Разбиваем размер секции на четыре байта, которые запишем далее в b.
  q = riff_chunk_size
  b = [] 
  for i in range(4):
      q, r = divmod(q, 256) # возьмем размер секции и вернем частное и остаток от деления на 256, и так 4 раза 
      b.append(r) # каждый из остатков добавим в список

  # Меняем байты c 4го по 7й вкл-но('\xff\xff\xff\xff') в output на b (типа '\xc62\x02\x00')
  riff = output[:4] + bytes(b) + output[8:]

  # класс io.BytesIO позволит работать с последовательностью байтов как с файловым объектом, а далее прочитаем как wav файл
  sr, audio = wav_read(io.BytesIO(riff)) # извлечём частоту дискретизации и полученный сигнал

  return audio, sr # функция вернет полученный сигнал и частоту дискретизации

# %% [markdown]
# ## Выполнение этой строчки кода приводт к началу записи аудио

# %%
audio, sr = get_audio() # запишем аудио через микрофон
# Out:
# <script>
# var my_div = document.createElement("DIV");
# var my_p = document.createElement("P");
# var my_btn = document.createElement("BUTTON");
# var t = document.createTextNode("Press to start recording");
#
# my_btn.appendChild(t);
# my_div.appendChild(my_btn);
# document.body.appendChild(my_div);
#
# var base64data = 0;  // будем использовать для аудиоданных метод кодирования информации в 64-разрядный код
# var reader;  // создаем переменную для чтения файла
# var recorder, gumStream; // объявляем переменные для записи данных/потока
# var recordButton = my_btn; //  создаем переменную для кнопки записи аудио с микрофона
#
# var handleSuccess = function(stream) {  // объявляем функцию для работы с потоками данных
#   gumStream = stream;  // создаем переменную для потока
#   var options = {
#     mimeType : 'audio/webm;codecs=opus' // в опциях задаем медиа тип с аудиоформатом и кодеками
#   };
#   recorder = new MediaRecorder(stream); // создаем новый объект MediaRecorder, получающий медиапоток для записи.
#   // MediaRecorder - интерфейс MediaStream Recording API представляющий функциональность для простой записи медиа. Создается..
#   // ..с использованием MediaRecorder() конструктора.
#   recorder.ondataavailable = function(e) {  // вызываем обработчик dataavailable события, запускаемое по окончанию записи
#     var url = URL.createObjectURL(e.data); // этим методом создаем DOMString(UTF-16 String), содержащий URL с указанием на объект e.data
#     var preview = document.createElement('audio'); // создаем элемент-тег аудио
#     preview.controls = true; // активизируем элементы управления
#     preview.src = url; // берем в кач-ве исходных данных файл, содержащийся в записанной ранее URL
#     document.body.appendChild(preview); //добавляем элемент аудио в <body>("тело", для хранения содержимого веб-страницы)
#
#     reader = new FileReader();  // создаем объект класса FileReader для чтения разных источников данных
#     reader.readAsDataURL(e.data);  // читаем содержимое указанного файла
#     reader.onloadend = function() {  // обработчик события, запускаемого после передачи данных
#       base64data = reader.result; // записываем прочитанное содержимое в base64data
#     }
#   };
#   recorder.start();  // начало записи медиа
#   };
#
# recordButton.innerText = "Идёт запись... нажмите для остановки"; // такой текст будет на кнопке BUTTON во время записи аудио
#
# // запрос разрешения пользователя на доступ к устройству захвата аудио(микрофон), указываем True
# navigator.mediaDevices.getUserMedia({audio: true}).then(handleSuccess);
#
#
# function toggleRecording() {  // функция опишет действия по завершению записи (после клика мышкой по кнопке "Recording... press to stop")
#   if (recorder && recorder.state == "recording") {  // если рекордер находится в процессе записи
#       recorder.stop();  // рекордер прерывается
#       gumStream.getAudioTracks()[0].stop();  // отключается запись и доступ к микрофону
#       recordButton.innerText = "Saving the recording... pls wait!" // эта надпись(сохранение записи) отобразится на кнопке BUTTON
#   }
# }
#
# function sleep(ms) {  // создаем функцию с задержкой вызова
#   return new Promise(resolve => setTimeout(resolve, ms));
#   // new Promise - конструкция для отложенных вычислений
#   // setTimeout позволяет вызвать функцию один раз через определённый интервал времени
# }
#
# var data = new Promise(resolve=>{
#   recordButton.onclick = ()=>{  // при нажатии левой кнопкой мыши на кнопку "Recording... press to stop"
#     toggleRecording()  // вызывается функция завершения аудиозаписи
#     sleep(2000).then(() => {  // и после задержки 2000мс(2 сек)
#       resolve(base64data.toString())  // полученные данные из формата base64 преобразовываем в строку
#     });
#   }
# });
#
# </script>

# %%
write(DIR + 'test.wav', sr, audio)

# %%
text = asr_model.transcribe([DIR + 'test.wav'])
# Out:
# Transcribing:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
text[0]
# Out:
# ['никифор ляпис трубецкой гаврилиада баллада о гангрене страдал гангрены гаврила гаврила от гангрены слег баллада об измене гаврила был неверным мужем гаврила же он изменял баллада об отмене служил гаврила бюрократом гаврила бюрократом был']
